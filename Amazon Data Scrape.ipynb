# %%
from lxml import html  
import csv,os,json
import requests
#from exceptions import ValueError
from time import sleep
 
def AmzonParser(url):
    headers = {'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/42.0.2311.90 Safari/537.36'}
    page = requests.get(url,headers=headers)
    while True:
        sleep(3)
        try:
            doc = html.fromstring(page.content)
            XPATH_NAME = '//h1[@id="title"]//text()'
            XPATH_SALE_PRICE = '//span[contains(@id,"ourprice") or contains(@id,"saleprice")]/text()'
            XPATH_ORIGINAL_PRICE = '//td[contains(text(),"List Price") or contains(text(),"M.R.P") or contains(text(),"Price")]/following-sibling::td/text()'
            XPATH_CATEGORY = '//a[@class="a-link-normal a-color-tertiary"]//text()'
            XPATH_AVAILABILITY = '//div[@id="availability"]//text()'
 
            RAW_NAME = doc.xpath(XPATH_NAME)
            RAW_SALE_PRICE = doc.xpath(XPATH_SALE_PRICE)
            RAW_CATEGORY = doc.xpath(XPATH_CATEGORY)
            RAW_ORIGINAL_PRICE = doc.xpath(XPATH_ORIGINAL_PRICE)
            RAw_AVAILABILITY = doc.xpath(XPATH_AVAILABILITY)
 
            NAME = ' '.join(''.join(RAW_NAME).split()) if RAW_NAME else None
            SALE_PRICE = ' '.join(''.join(RAW_SALE_PRICE).split()).strip() if RAW_SALE_PRICE else None
            CATEGORY = ' > '.join([i.strip() for i in RAW_CATEGORY]) if RAW_CATEGORY else None
            ORIGINAL_PRICE = ''.join(RAW_ORIGINAL_PRICE).strip() if RAW_ORIGINAL_PRICE else None
            AVAILABILITY = ''.join(RAw_AVAILABILITY).strip() if RAw_AVAILABILITY else None
 
            if not ORIGINAL_PRICE:
                ORIGINAL_PRICE = SALE_PRICE
 
            if page.status_code!=200:
                raise ValueError('captha')
            data = {
                    'NAME':NAME,
                    'SALE_PRICE':SALE_PRICE,
                    'CATEGORY':CATEGORY,
                    'ORIGINAL_PRICE':ORIGINAL_PRICE,
                    'AVAILABILITY':AVAILABILITY,
                    'URL':url,
                    }
 
            return data
        except Exception as e:
            e
 
def ReadAsin():
    # AsinList = csv.DictReader(open(os.path.join(os.path.dirname(__file__),"Asinfeed.csv")))
    AsinList = ['B0046UR4F4',
    'B00JGTVU5A',
    'B00GJYCIVK',
    'B00EPGK7CQ',
  # 'B00EPGKA4G',
  # 'B00YW5DLB4',
  # 'B00KGD0628',
  # 'B00O9A48N2',
  # 'B00O9A4MEW',
    #'6428320',
    #'14072149',
    'B00UZKG8QU']
    extracted_data = []
    #extracted_data.append(AsinList)
    print(extracted_data)
    for i in AsinList:
        url = "http://www.amazon.com/dp/"+i
        print("Processing: "+url)
        extracted_data.append(AmzonParser(url))
        sleep(5)
    print(extracted_data)
    f=open('data.json','w')
    json.dump(extracted_data,f,indent=4)
 
 
if __name__ == "__main__":
    ReadAsin()
# Out:
# []
# Processing: http://www.amazon.com/dp/B0046UR4F4
# Processing: http://www.amazon.com/dp/B00JGTVU5A
# Processing: http://www.amazon.com/dp/B00GJYCIVK
# Processing: http://www.amazon.com/dp/B00EPGK7CQ
# Processing: http://www.amazon.com/dp/B00UZKG8QU
# [{'NAME': 'G-Technology G-SPEED eS PRO High-Performance Fail-Safe RAID Solution for HD/2K Production 8TB (0G01873)', 'SALE_PRICE': None, 'CATEGORY': 'Electronics > Computers & Accessories > Data Storage > External Hard Drives', 'ORIGINAL_PRICE': None, 'AVAILABILITY': 'Available from these sellers.', 'URL': 'http://www.amazon.com/dp/B0046UR4F4'}, {'NAME': 'G-Technology G-DRIVE ev USB 3.0 Hard Drive 500GB (0G02727)', 'SALE_PRICE': '$89.95', 'CATEGORY': 'Electronics > Computers & Accessories > Data Storage > External Hard Drives', 'ORIGINAL_PRICE': '$89.95', 'AVAILABILITY': 'Only 2 left in stock - order soon.', 'URL': 'http://www.amazon.com/dp/B00JGTVU5A'}, {'NAME': 'G-Technology G-DRIVE PRO with Thunderbolt High Speed Portable RAID Solution 2TB (0G02828)', 'SALE_PRICE': '$269.99', 'CATEGORY': 'Electronics > Computers & Accessories > Data Storage > External Hard Drives', 'ORIGINAL_PRICE': '$269.99', 'AVAILABILITY': 'In Stock.', 'URL': 'http://www.amazon.com/dp/B00GJYCIVK'}, {'NAME': 'G-Technology G-SPEED Q High-Performance 4-Bay RAID Storage Solution 8TB (USB3.0/eSATA/FireWire 800) (0G02836)', 'SALE_PRICE': None, 'CATEGORY': 'Electronics > Computers & Accessories > Data Storage > External Hard Drives', 'ORIGINAL_PRICE': None, 'AVAILABILITY': "Currently unavailable.\n        \n        \n    \n    \n    \n    \n\n\n\n    \n    \n         \n        \n        \n            We don't know when or if this item will be back in stock.", 'URL': 'http://www.amazon.com/dp/B00EPGK7CQ'}, {'NAME': 'G-Technology G-RAID USB Removable Dual Drive Storage System 8TB (0G04069)', 'SALE_PRICE': None, 'CATEGORY': 'Electronics > Computers & Accessories > Data Storage', 'ORIGINAL_PRICE': None, 'AVAILABILITY': 'Available from these sellers.', 'URL': 'http://www.amazon.com/dp/B00UZKG8QU'}]

# %%
import pandas as pd

df_ProductData = pd.read_json('data.json')

# %%
df_ProductData
# Out:
#                          AVAILABILITY  \
# 0       Available from these sellers.
# 1  Only 2 left in stock - order soon.
# 2       Available from these sellers.
#
#                                             CATEGORY  \
# 0  Electronics > Computers & Accessories > Data S...
# 1  Electronics > Computers & Accessories > Data S...
# 2  Electronics > Computers & Accessories > Data S...
#
#                                                 NAME ORIGINAL_PRICE  \
# 0  G-Technology G-SPEED eS PRO High-Performance F...           None
# 1  G-Technology G-DRIVE ev USB 3.0 Hard Drive 500...         $89.95
# 2  G-Technology G-RAID USB Removable Dual Drive S...           None
#
#   SALE_PRICE                                  URL
# 0       None  http://www.amazon.com/dp/B0046UR4F4
# 1     $89.95  http://www.amazon.com/dp/B00JGTVU5A
# 2       None  http://www.amazon.com/dp/B00UZKG8QU

# %%
AsinList = ['B0046UR4F4',
    'B00JGTVU5A',
  # 'B00GJYCIVK',
  # 'B00EPGK7CQ',
  # 'B00EPGKA4G',
  # 'B00YW5DLB4',
  # 'B00KGD0628',
  # 'B00O9A48N2',
  # 'B00O9A4MEW',
    'B00UZKG8QU',]

df_ProductData['Asin'] = AsinList

# %%
df_ProductData
# Out:
#                          AVAILABILITY  \
# 0       Available from these sellers.
# 1  Only 2 left in stock - order soon.
# 2       Available from these sellers.
#
#                                             CATEGORY  \
# 0  Electronics > Computers & Accessories > Data S...
# 1  Electronics > Computers & Accessories > Data S...
# 2  Electronics > Computers & Accessories > Data S...
#
#                                                 NAME ORIGINAL_PRICE  \
# 0  G-Technology G-SPEED eS PRO High-Performance F...           None
# 1  G-Technology G-DRIVE ev USB 3.0 Hard Drive 500...         $89.95
# 2  G-Technology G-RAID USB Removable Dual Drive S...           None
#
#   SALE_PRICE                                  URL        Asin
# 0       None  http://www.amazon.com/dp/B0046UR4F4  B0046UR4F4
# 1     $89.95  http://www.amazon.com/dp/B00JGTVU5A  B00JGTVU5A
# 2       None  http://www.amazon.com/dp/B00UZKG8QU  B00UZKG8QU
